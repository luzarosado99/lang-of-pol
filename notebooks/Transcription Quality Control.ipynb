# %%
import pandas as pd
import pydub

# %%
# Two basic quality control strategies:
#  1. Ask workers to transcribe "gold standard" audio then assess performance (speed vs. accuracy)
#  2. Insert audio snippets with known transcriptions into assigned files at random then check once finished (accuracy)

# %%
# Strategy 1:
# - Identify "gold standard" file and accompanying transcription
# - Create function to assess accuracy of transcription

# %%
# Strategy 2:
# - Build dictionary of transcribed snippets (as context-free as possible)
# - Randomly decide how many to include in a file
# - Randomly select the appropriate number of snippets from the dictionary
# - Randomly select when/where to add snippets
# - Combine non-silent snippets and QC snippets, building dict of timing/labels for QC snippets
# - Assign file, receive student transcription
# - Look for QC snippets based on timing (need a window, much easier now with artificial silences)
# - Extract QC snippets from transcript
# - Save transcript without QC snippets
# - Assess error rate in QC snippet transcriptions
# - Save QC snippet error rate as metadata

# %% [markdown]
# # Build dict of {audio:transcription}

# %%
# Find audio where transcribers agree on transcription 
df = pd.read_csv('transcripts.csv')
df.head()
# Out:
#     feed   zone  year  month  day  time    sid         start           end  \
# 0  27730  Zone1  2018      8   12   932  RADIO  00.02.21.252  00.02.31.279
# 1  27730  Zone1  2018      8   12   932  RADIO  00.02.38.109  00.02.39.417
# 2  27730  Zone1  2018      8   12   932   UNIT  00.02.48.327  00.02.49.235
# 3  27730  Zone1  2018      8   12   932   UNIT  00.02.55.330  00.02.57.437
# 4  27730  Zone1  2018      8   12   932  RADIO  00.03.04.003  00.03.09.017
#
#                                        transcription notes  \
# 0  RADIOSHOP TESTING ONE TWO THREE FOUR FIVE FIVE...   NaN
# 1                                    ONE TWO ONE TWO   NaN
# 2                                     UNIT COMING IN   NaN
# 3                    ZONE ONE IS ON CITY [WIDE] FIVE   NaN
# 4  OKAY THANKS UH THIS IS THE RADIO SHOP TESTING ...   NaN
#
#                               file transcriber       start_c  \
# 0  201808120932-28710-27730ah.xlsx   huthealex  00.02.21.252
# 1  201808120932-28710-27730ah.xlsx   huthealex  00.02.38.109
# 2  201808120932-28710-27730ah.xlsx   huthealex  00.02.48.327
# 3  201808120932-28710-27730ah.xlsx   huthealex  00.02.55.330
# 4  201808120932-28710-27730ah.xlsx   huthealex  00.03.04.003
#
#                      start_dt         end_c                      end_dt  \
# 0  1900-01-01 00:02:21.252000  00.02.31.279  1900-01-01 00:02:31.279000
# 1  1900-01-01 00:02:38.109000  00.02.39.417  1900-01-01 00:02:39.417000
# 2  1900-01-01 00:02:48.327000  00.02.49.235  1900-01-01 00:02:49.235000
# 3  1900-01-01 00:02:55.330000  00.02.57.437  1900-01-01 00:02:57.437000
# 4  1900-01-01 00:03:04.003000  00.03.09.017  1900-01-01 00:03:09.017000
#
#                       length  length_s
# 0  0 days 00:00:10.027000000    10.027
# 1  0 days 00:00:01.308000000     1.308
# 2  0 days 00:00:00.908000000     0.908
# 3  0 days 00:00:02.107000000     2.107
# 4  0 days 00:00:05.014000000     5.014

# %%
df_grouped_files = df.groupby(['feed','zone','year','month','day','time'])
same_text = []
for f, f_df in df_grouped_files:
    transcribers = f_df['transcriber'].unique().tolist()
    if len(transcribers)>1:
        f_df1 = f_df[f_df['transcriber']==transcribers[0]]
        f_df2 = f_df[f_df['transcriber']==transcribers[1]]
        same_text += [list(f)+f_df1.loc[f_df1['transcription'].isin(f_df2['transcription']),'transcription'].tolist()]
len(same_text), len(df_grouped_files)
# Out:
# (62, 125)

# %%
same_text
# Out:
# [[27730,
#   'Zone1',
#   2018,
#   8,
#   4,
#   2331,
#   'SIXTEEN TWENTY TWO ROBERT',
#   'TWENTY TWO',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'TWENTY FOUR ROBERT',
#   'THANK YOU',
#   'THIRTEEN ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'FOUR ROBERT',
#   'NO',
#   'SIXTEEN FOURTEEN ROBERT',
#   'FOURTEEN ROBERT',
#   'TEN FOUR',
#   'SIXTEEN ELEVEN ROBERT',
#   'ELEVEN ROBERT',
#   'TWENTY THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'FIVE THREE SEVEN FOUR',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'ONE SIX THREE THREE ROBERT',
#   'NO THEY RETURNED TO QUARTERS',
#   'NOW SEVENTEEN THIRTEEN ROBERT',
#   'OH',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'ONE SIX TWO FOUR ROBERT',
#   'ONE SIX TWO FOUR ROBERT',
#   'SEVEN TWENTY THREE ROBERT',
#   'SEVENTEEN NINETY FIVE ROBERT',
#   'ONE SEVEN NINE FIVE ROBERT',
#   'SEVENTEEN NINETY FIVE',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'VERY GOOD THANK YOU',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'THIRTY THREE ROBERT',
#   'WONDERFUL',
#   'TWENTY ONE ROBERT',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'THIRTEEN ROBERT',
#   'SIXTEEN TWENTY TWO ROBERT',
#   'TWENTY TWO',
#   'THANK YOU',
#   'THIRTEEN ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN EIGHTY EIGHT ROBERT',
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'THIRTY FOUR ROBERT',
#   'TEN FOUR',
#   'TWENTY THREE ROBERT',
#   'ARE THEY FLASHING RED YELLOW GREEN',
#   'ALL DIRECTIONS OR',
#   'YEAH ALL DIRECTIONS',
#   'SIXTEEN THIRTY FOUR ROBERT FOR INFO',
#   'THIRTY FOUR',
#   'TEN FOUR',
#   'SEVENTEEN TWELVE ROBERT',
#   'SEVENTEEN TWELVE ROBERT',
#   'SEVENTEEN THIRTY TWO ROBERT',
#   'ONE SIX ONE THREE ROBERT',
#   'ONE SIX THREE THREE ROBERT FOR THE MOBILE WITH FIFTY THREE SEVENTY FOUR',
#   'TEN FOUR',
#   'TEN FOUR',
#   'NO',
#   'SIXTEEN TWENTY ROBERT',
#   'SIXTEEN TWENTY ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   1,
#   'SIXTEEN TWENTY ROBERT',
#   'SIXTEEN TWENTY ROBERT',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'ONE SIX TWO THREE ROBERT',
#   'NEGATIVE',
#   'SIXTEEN ELEVEN ROBERT',
#   'NINETY NINE',
#   'SIXTEEN TWELVE ROBERT',
#   'SIX TWELVE ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'IS THAT SIXTEEN TWENTY THREE ROBERT',
#   'ONE FOUR ROBERT',
#   'SIX ONE FOUR ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'TEN FOUR',
#   'TWENTY FOUR ROBERT',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'ONE SIX THREE TWO ROBERT',
#   'OKAY',
#   'ONE SEVEN TWO THREE ROBERT',
#   'ONE SEVEN TWO THREE ROBERT',
#   'WHAT KIND OF MISSION IS IT',
#   'OKAY',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'SIXTEEN THIRTEEN ROBERT',
#   'OKAY THIRTEEN ROBERT OKAY',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'ONE SIX TWO ONE ROBERT',
#   'TEN FOUR',
#   'EIGHTEEN NINETY FIVE ROBERT',
#   'NINETY FIVE ROBERT',
#   'TEN FOUR',
#   'SIX SEVENTEEN THIRTY TWO ROBERT FOR INFO',
#   'SIX TWO ROBERT',
#   'ONE SIX TWO TWO ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY TWO ROBERT',
#   'ROBERT',
#   'ALRIGHT THANK YOU',
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'THIRTY FOUR ROBERT',
#   'TEN FOUR',
#   'SIXTEEN FOURTY ONE ROBERT',
#   'SIXTEEN ELEVEN ROBERT',
#   'ONE SIX ONE ONE ROBERT',
#   'TWENTY ROBERT GO AHEAD',
#   'ALRIGHT YOU COPY',
#   'ELEVEN ROBERT YOU COPY HE SAID GO AHEAD',
#   'SO TWELVE ROBERT YOU CLEAR',
#   'SIXTEEN THIRTEEN ROBERT',
#   'SO SIXTEEN TWELVE ROBERT AGAIN',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'THANKS FOURTEEN ROBERT FOR YOUR HELP OVER THERE WITH TWENTY ONE ROBERT',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'TWENTY ONE ROBERT',
#   'TEN FOUR',
#   'SIXTEEN THIRTY ONE ROBERT',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'FOUR ROBERT',
#   'OKAY',
#   'SEVENTEEN TEN ROBERT',
#   'SEVEN ONE ZERO ROBERT',
#   'TRY IT NOW',
#   'SEVEN TWO TWO ROBERT',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'ONE SEVEN TWO THREE ROBERT',
#   'SEVENTEEN THIRTY ONE ROBERT FOR INFO',
#   'NO I HAVE YOU CLEAR NO PROBLEM I HAVE YOU CLEAR',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'ONE SIX TWO FOUR ROBERT',
#   'TWENTY FOUR ROBERT',
#   'ONE SEVEN NINE SEVEN',
#   'ONE SEVEN NINE SEVEN',
#   'TEN FOUR',
#   'SIXTEEN TWELVE ROBERT',
#   'SIX TWELVE ROBERT',
#   'TEN FOUR',
#   'TEN FOUR',
#   'ONE SEVEN NINE FIVE',
#   'ONE SEVEN TWO TWO ROBERT',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'ONE SEVEN TWO TWO ROBERT',
#   'TWENTY TWO ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'OKAY'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   31,
#   'SIXTEEN FOURTEEN ROBERT',
#   'FOURTEEN ROBERT',
#   'TEN FOUR',
#   'SEVEN THREE ONE ROBERT',
#   'SEVEN THREE ONE ROBERT',
#   'SIXTEEN THIRTEEN ROBERT',
#   'ONE SIX ONE THREE ROBERT',
#   'SIX ONE THREE ROBERT',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'SEVENTEEN ELEVEN ROBERT',
#   'THANKS',
#   'SIXTEEN FOURTEEN ROBERT',
#   'SIXTEEN FOURTEEN ROBERT',
#   'SIXTEEN ELEVEN ROBERT',
#   'SEVENTEEN ELEVEN ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWELVE ROBERT',
#   'SIX TWELVE ROBERT',
#   'TEN FOUR',
#   'SIX ONE FOUR ROBERT',
#   'SURE GO AHEAD WITH IT',
#   'SIX TWO FOUR SIX NINE THREE NINE SIX EIGHT NINE ONE UNION',
#   'TEN FOUR',
#   'SIXTEEN THIRTEEN ROBERT',
#   'SIXTEEN THIRTEEN ROBERT',
#   'TEN FOUR',
#   'SEVEN TWO THREE ROBERT',
#   'SEVEN TWO THREE ROBERT',
#   'SIXTEEN TWENTY TWO ROBERT',
#   'SEVENTEEN THIRTY THREE ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN ELEVEN ROBERT',
#   'SEVENTEEN ELEVEN ROBERT',
#   'SIXTEEN TWELVE ROBERT',
#   'SIX TWELVE ROBERT',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWELVE ROBERT',
#   'RAVENSWOOD MANNER PARK TEN FOUR',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'TEN FOUR',
#   'ONE SEVEN TWO FOUR ROBERT',
#   'FOUR ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'FOUR ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   100,
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'FOUR ROBERT',
#   'TWENTY FOUR ROBERT',
#   'SIX FOURTEEN ROBERT',
#   'SIX ONE FOUR ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'SEVENTY TWO ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'TEN FOUR',
#   'ELEVEN ROBERT',
#   'TEN FOUR',
#   'ALRIGHT SCREAM REAL LOUD IF YOU NEED HELP THANK YOU',
#   'THIRTEEN ROBERT',
#   'PLEASE THANK YOU',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'SEVENTEEN THIRTY THREE ROBERT',
#   'THIRTY THREE ROBERT',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'GUESS WE’LL TRY IT',
#   'SEVEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'OKAY',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'SEVENTEEN TWENTY ROBERT',
#   'SEVENTEEN TEN ROBERT I’LL TAKE A LOOK AT IT',
#   'SIXTEEN TWELVE ROBERT',
#   'SIXTEEN TWELVE ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TEN ROBERT',
#   'TEN ROBERT',
#   'NOPE',
#   'AND THANK GOD IT’S FRIDAY',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'OKAY THANKS',
#   'SIX TWELVE ROBERT',
#   'TWELVE ROBERT',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'TWENTY ONE ROBERT',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVENTEEN THIRTY THREE ROBERT',
#   'THIRTY THREE ROBERT',
#   'WHAT’S THE PLATE',
#   'TEN FOUR',
#   'OKAY',
#   'SIXTEEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'ALRIGHT',
#   'OKAY',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SURE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   130,
#   'TEN FOUR',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SURE',
#   'TEN FOUR',
#   'NINETY SEVEN',
#   'ALRIGHTY',
#   'SEVENTEEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'SHE WAS A THIRD PARTY CALLER GOING DOWN THE STREET',
#   'SOUNDS GOOD',
#   'SEVEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'CORRECT',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'TWENTY FOUR ROB',
#   'TEN FOUR',
#   'I GUESS TWENTY FOUR SHERRY SEES YOU SITTING IN THE LOT SO SHE’S WALKING OVER TO YOUR CAR',
#   'SIXTEEN THIRTY ONE ROBERT',
#   'SIXTEEN THIRTY ONE ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'SEVEN TWO FOUR ROBERT',
#   'SURE',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'SEVEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'GIVE ME A FEW MINUTES',
#   'SEVENTEEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'OKAY SIXTEEN THIRTY THREE ROBERT',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVEN THREE ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'THIRTEEN ROBERT',
#   'SEVEN TWO THREE ROBERT',
#   'TEN FOUR',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'TWO THREE ROBERT',
#   'SEVENTEEN THREE ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'ALRIGHT',
#   'TEN FOUR',
#   'SIXTEEN TWENTY ONE ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'ONE SIX TWO FOUR ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'TWENTY FOUR ROBERT',
#   'TEN FOUR',
#   'ELEVEN ROBERT',
#   'SEVEN TWO THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'SEVENTEEN THIRTY ONE ROBERT',
#   'FOUR ZERO FOUR SEVEN SEVEN'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   200,
#   'SEVENTEEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'FOUR ZERO FOUR SEVEN',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'TEN FOUR',
#   'SIXTEEN TWELVE ROBERT',
#   'SIXTEEN TWELVE ROBERT',
#   'TEN FOUR',
#   'ALRIGHT I GOT THE WAGON COMING OVER THERE',
#   'SIXTEEN THIRTEEN ROBERT WE’LL GO',
#   'OH DIDN’T KNOW YOU WERE CIT CERTIFIED',
#   'OH TWO',
#   'SEVEN TWO THREE ROBERT',
#   '[TEN FOUR]',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'ONE SIX TWO FOUR ROBERT',
#   'SIXTEEN TWENTY ONE ROBERT',
#   '[TEN FOUR]',
#   'TEN FOUR',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'SEVEN TWO THREE ROBERT',
#   'TWENTY THREE ROBERT',
#   'TWO FIFTEEN',
#   'SEVENTEEN THIRTY TWO ROBERT',
#   '[TEN FOUR]',
#   'SEVEN OH ONE',
#   'SEVEN OH ONE',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'THIRTY ONE ROBERT',
#   'SEVENTEEN THIRTY ONE ROBERT',
#   'SEVEN THIRTY ONE ROBERT',
#   'OKAY',
#   'SEVEN TWO FOUR ROBERT',
#   'SEVEN TWO FOUR ROBERT',
#   'TEN FOUR',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'THIRTY TWO ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'TWENTY TWO ROBERT',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   230,
#   'SIX TWO TWO ROBERT',
#   'TWENTY TWO ROBERT',
#   'SIXTEEN TWENTY ROBERT',
#   'TEN FOUR',
#   'SIXTEEN THIRTY THREE ROBERT',
#   'THIRTY THREE ROBERT',
#   'SEVEN TWO THREE ROBERT',
#   'SEVEN TWO THREE ROBERT',
#   '[TEN FOUR]',
#   'SIXTEEN THIRTY FOUR ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   330,
#   'SIXTEEN THIRTY THREE ROBERT',
#   'SIXTEEN THIRTEEN ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'SEVENTEEN THIRTEEN ROBERT',
#   'OF COURSE',
#   'SEVENTEEN TWENTY ROBERT',
#   'TWENTY ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'SEVENTEEN TWENTY THREE ROBERT',
#   'IF YOU CAN TRANSLATE THAT WORD LET ME KNOW',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'SEVEN TWENTY TWO ROBERT',
#   'OKAY',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'ONE SEVEN TWO TWO ROBERT',
#   'SEVEN TWO FOUR ROBERT',
#   'SEVEN TWO FOUR ROBERT',
#   'SEVEN THREE ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'I GET IT OKAY',
#   'SIXTEEN NINETY NINE ROBERT',
#   'NINETY NINE ROBERT GOOD MORNING',
#   'ALRIGHTY SIXTEEN ELEVEN ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   359,
#   'FOURTEEN ROBERT',
#   'FOUR O’CLOCK',
#   'SEVENTEEN TWENTY ROBERT',
#   'SEVENTEEN TWENTY ROBERT',
#   'THIRTY TWO ROBERT',
#   'SIXTEEN TWELVE ROBERT',
#   'OKAY',
#   'NINETY FIVE ROBERT',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'TWENTY FOUR ROBERT',
#   'OKAY',
#   'SEVEN THIRTY ONE ROBERT',
#   'THIRTY ONE ROBERT',
#   'ZERO THREE FIVE ONE FIVE',
#   'SEVENTEEN THIRTY TWO ROBERT',
#   'THIRTY TWO ROBERT',
#   'ALRIGHT',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'ONE SIX TWO THREE ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   429,
#   'SIXTEEN TWENTY THREE ROBERT',
#   'SIXTEEN TWENTY THREE ROBERT',
#   'ONE SEVEN NINETY FIVE ROBERT',
#   'ONE SEVEN NINE FIVE ROBERT',
#   'NINETY FIVE ROBERT',
#   'SEVENTEEN TWELVE ROBERT',
#   'TAKE THE ACCIDENT OVER AT PETERSON AND JERSEY CAR UNDERNEATH A SEMI',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'TWENTY TWO ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'TEN FOUR',
#   'HANG ON LET ME CHECK',
#   'THANK YOU'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   459,
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'THIRTY FOUR ROBERT',
#   'TWENTY THREE ROBERT',
#   'SEVENTEEN NINETY FIVE',
#   'SEVEN NINETY FIVE ROBERT',
#   'SEVEN NINETY FIVE ROBERT',
#   'SIXTEEN TWENTY FOUR ROBERT',
#   'TWENTY FOUR ROBERT',
#   'SEVENTEEN THIRTY TWO ROBERT',
#   'SEVENTEEN THIRTY TWO ROBERT',
#   'TWO ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'SEVENTY TWO ROBERT',
#   'TEN FOUR',
#   'TWELVE ROBERT',
#   'IT ABSOLUTELY IS',
#   'IS THE PERSON OUT OF THAT VEHICLE',
#   'OKAY WHAT KIND OF CAR IS IT',
#   'NISSAN ULTIMA',
#   'COLOR',
#   'BLACK',
#   'PLATE NUMBER',
#   'QUEEN NINE SEVEN ONE FIVE SIX NINE',
#   'IS IT GONNA ROLL OR FLOAT',
#   'OKAY',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY ROBERT',
#   'TWENTY ROBERT',
#   'FROM THE ACCIDENT',
#   'OKAY',
#   'SEVENTEEN TWENTY ROBERT',
#   'TWENTY ROBERT',
#   'OKAY',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'TWENTY TWO ROBERT',
#   'TEN FOUR',
#   'TWENTY TWO ROBERT',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   529,
#   'SIXTEEN TWELVE ROBERT',
#   'OKAY',
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'ONE SIX THREE FOUR ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY TWO ROBERT',
#   'TWENTY TWO ROBERT',
#   'TEN FOUR',
#   'TEN FOUR',
#   'YEAH THE TROLLS ARE BRINGING THEM TODAY',
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'SIXTEEN THIRTY FOUR ROBERT',
#   'THIRTY FOUR ROBERT',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   559,
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE',
#   'TEN FOUR',
#   'ONE SIX TWO ONE',
#   'TWENTY ONE GOOD MORNING',
#   'ALRIGHT TRY IT NOW SIR',
#   '[…]',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'SIXTEEN TWENTY THREE',
#   'TEN FOUR',
#   'SIXTEEN THIRTY TWO ROBERT',
#   'SEVENTEEN THIRTEEN',
#   'THIRTEEN',
#   'NINETY NINE […]',
#   'TEN FOUR',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'SEVENTEEN SEVENTY TWO ROBERT',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVEN THIRTEEN',
#   '[…]',
#   'SEVEN TWELVE ROBERT',
#   'TWELVE ROBERT',
#   'SEVEN ONE THREE',
#   'ALRIGHT TEN FOUR',
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE',
#   'TEN FOUR',
#   'SEVENTEEN ELEVEN',
#   'SEVEN ELEVEN',
#   'ALRIGHT THANKS'],
#  [27730, 'Zone1', 2018, 8, 5, 629, 'TEN FOUR', 'SEVENTEEN THIRTEEN'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   658,
#   'SIXTEEN TWENTY THREE',
#   'TEN FOUR',
#   'SEVENTEEN TWELVE ROBERT',
#   'SEVENTEEN TWELVE ROBERT',
#   'SEVENTEEN THIRTEEN',
#   'SEVENTEEN ELEVEN',
#   'THIRTEEN SIR',
#   'SEVENTEEN OH TWO',
#   'SEVENTEEN OH TWO',
#   'SEVENTEEN NINETY FIVE',
#   'ALRIGHT OH TWO',
#   'SEVENTEEN ELEVEN',
#   'THIRTY THREE GO AHEAD',
#   'TEN FOUR SIR',
#   'SIX FIVE TWO',
#   'SIX FIVE TWO GOOD MORNING',
#   'ALRIGHT TEN FOUR',
#   'THANK YOU',
#   'ALRIGHT TEN FOUR GOOD MORNING'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   758,
#   'SEVENTEEN NINETY NINE RADIO CHECK',
#   'SEVENTEEN NINETY NINE GOOD MORNING AND THAT IS A GOOD SIGNAL',
#   'SIXTEEN TWELVE',
#   'SIX TWELVE',
#   'FIVE EIGHT FOUR TWO ON HARLEM',
#   'SEVEN TWENTY',
#   'TEN FOUR GOOD MORNING SEVEN NINE FIVE',
#   'SEVEN TWENTY',
#   'NO NOTHING',
#   'SEVEN TWENTY',
#   'ALRIGHT GOOD MORNING NINETY FIVE',
#   'MORNING SUNSHINE',
#   'SEVEN TWENTY',
#   'SEVEN TWENTY'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   828,
#   'SEVENTEEN TWENTY',
#   'SEVEN TWENTY',
#   'SEVEN TWELVE',
#   'TEN FOUR',
#   'YES OF COURSE GO AHEAD WITH THE INFORMATION',
#   'ALRIGHT',
#   'TEN FOUR',
#   'SEVENTEEN SEVENTY TWO',
#   'SEVENTEEN SEVENTY TWO',
#   'TEN FOUR',
#   'SIX FOURTEEN',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY THREE',
#   'TEN FOUR',
#   'SEVEN TWENTY',
#   'SEVENTEEN TWENTY',
#   'YES SIR GO AHEAD',
#   'TEN FOUR',
#   'ALRIGHT SEVENTEEN TWENTY FOUR',
#   'SEVEN TWENTY TWO FOR THE ASSIST',
#   'SIX THREE FOUR',
#   'TWENTY TWO',
#   'SEVEN TWENTY',
#   'SEVENTEEN ELEVEN',
#   'ELEVEN NINETY NINE',
#   'SEVEN TWENTY',
#   'SEVEN TWELVE',
#   'TEN FOUR',
#   'YEAH WE COULD PROBABLY USE A FEW MORE TOW REPORTS',
#   'SEVEN THREE ONE',
#   'SEVEN THIRTEEN',
#   'SEVEN THIRTEEN',
#   'SEVEN THIRTY ONE IS SAYING TAKE A DISREGARD AND COME BACK TO THE STATION',
#   'OKAY THANK YOU',
#   'TEN FOUR THANK YOU',
#   'SEVEN TWELVE',
#   'SEVENTEEN SEVENTY TWO',
#   'SEVENTEEN SEVENTY TWO',
#   'TEN FOUR',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVENTEEN ELEVEN',
#   'SEVENTEEN ELEVEN',
#   'TEN FOUR',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   5,
#   1725,
#   'SIXTEEN THIRTY TWO',
#   'SIXTEEN THIRTY TWO',
#   'TEN FOUR',
#   'SEVEN TWENTY TWO',
#   'TEN FOUR',
#   'SIXTEEN TWENTY TWO',
#   'TWENTY TWO',
#   'MONTROSE AND AUSTIN',
#   'YES',
#   'TEN FOUR GO AHEAD',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVENTEEN ELEVEN',
#   'SEVEN ELEVEN'],
#  [27730, 'Zone1', 2018, 8, 11, 1508, 'FOUR NINE ZERO ZERO FORTY NINE HUNDRED'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   1538,
#   'SIX ELEVEN',
#   'SEVENTEEN THIRTY THREE',
#   'OKAY TEN FOUR',
#   'SIXTEEN THIRTY FOUR',
#   'WHAT UNIT IS THIS',
#   'SEVENTEEN THIRTY ONE',
#   'SEVEN THIRTY ONE',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   1608,
#   'SIX THIRTY FOUR',
#   'TEN FOUR',
#   'SIX TWELVE',
#   'OKAY TEN FOUR THANK YOU',
#   'SIXTEEN TWENTY THREE',
#   'SIX TWENTY THREE',
#   'SIX',
#   'ONE SIX ONE TWO',
#   'TEN FOUR',
#   'SEVEN ONE TWO ONE SEVEN ONE TWO',
#   'ONE SIX THREE ONE',
#   'THIRTY ONE',
#   'YEAH SEVENTEEN THIRTY SHOULD BE FINE IT JUST HIT THE BOARD A MINUTE AGO',
#   "OH THAT'S WHAT I WAS TRYING TO FIGURE OUT",
#   'ONE SIX THREE ONE',
#   'SIX THIRTY ONE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   1638,
#   'SEVENTEEN THIRTY TWO',
#   'THIRTY TWO',
#   'TEN EIGHT FIVE HUNDRED ON ZONE ONE',
#   'SIXTEEN THIRTY THREE',
#   'THREE THREE IS EVERYTHING SECURE OVER THERE',
#   "YEAH IT'S ALL SECURE",
#   'YEAH BY AMBULANCE',
#   'ALRIGHT THANK YOU',
#   'TEN FOUR',
#   'TWELVE',
#   'TEN FOUR THANK YOU',
#   'ALRIGHT',
#   'ONE SIX TWO FOUR',
#   'SIX TWO FOUR',
#   'ALRIGHT',
#   'HEY SIXTEEN THIRTY THREE CAN YOU COPY',
#   'THANKS',
#   'YOU SAID A SLOW DOWN, WHAT DO YOU MEAN',
#   'TWENTY ONE OR SEVENTY ONE',
#   'ALRIGHT',
#   "ALRIGHT I'LL CHANGE THE LOCATION",
#   'SIXTEEN THIRTY TWO',
#   'THIRTY TWO',
#   "I'M SORRY"],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   1708,
#   'ONE SIX ONE FOUR',
#   'USE CAUTION',
#   'SIXTEEN ELEVEN',
#   'SIXTEEN ELEVEN',
#   'AND THIS WAS THE SISTER CALLING IN FOR HER',
#   'SIX FOURTEEN',
#   'NEW JERSEY',
#   'THREE TWO',
#   'OKAY',
#   'SEVENTEEN NINETY SEVEN YOU OUT YET',
#   'ONE SEVEN ONE TWO'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   2007,
#   'TEN FOUR',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SIX SIX ONE',
#   'TEN FOUR',
#   '<X> ',
#   'TEN FOUR',
#   'WEARING BLACK',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVEN TWO',
#   'TEN FOUR',
#   'SEVEN TWO TWO',
#   'SEVEN TWO TWO',
#   'SIX THIRTEEN',
#   'SEVEN TWO TWO',
#   'UM WE COULD TRY',
#   'TEN FOUR',
#   'SEVEN THREE ONE',
#   'FOUR THANK YOU',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SIXTEEN TWELVE',
#   '<X> OVER HERE',
#   'TEN FOUR',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   2036,
#   'TEN FOUR',
#   '<X>',
#   'TEN FOUR',
#   '<X>',
#   'TEEN',
#   'SEVEN TWENTY TWO',
#   '<X>',
#   'SEVEN TWENTY TWO',
#   '<X>',
#   'TEN FOUR',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   2106,
#   'TWO FOUR ON THE WAY',
#   '<X>',
#   '<X>',
#   'SIX TWO TWO',
#   '<X>',
#   'ROBERT',
#   '<X>'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   2136,
#   '<X>',
#   '<X>',
#   'SIXTEEN THIRTY THREE SQUAD EN ROUTE',
#   '<X>',
#   'TWENTY FOUR',
#   'OKAY YOU HEADED OVER THERE',
#   'SIXTEEN ELEVEN ROBERT',
#   'SIXTEEN ELEVEN ROBERT',
#   '<X>',
#   '<X>',
#   'ELEVEN ROB',
#   'AND ACTUALLY IT SAYS IN HERE',
#   '<X> PARKED OVER THERE',
#   'SIXTEEN UH TWENTY FOUR',
#   'TWO FOUR',
#   'SCREAM IF YOU NEED HELP',
#   'TWENTY',
#   'TWENTY',
#   'SEVENTEEN FIFTY THREE',
#   'SUSPICIOUS AUTO WITH OCCUPANTS AT LAWRENCE AND CICERO GOING EASTBOUND',
#   'EASTBOUND',
#   'SIXTEEN SEVENTY ONE ROBERT',
#   'TWENTY ONE ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   2206,
#   'SIXTEEN',
#   '<X>',
#   'SIXTEEN THIRTY ONE ROBERT',
#   '<X>',
#   '<X>',
#   'SEVENTEEN FIFTY FOUR',
#   "DIDN'T UNDERSTAND A WORD OF THAT WITH ALL THE STATIC IN YOUR RADIO",
#   'SIXTEEN THIRTY THREE OR SEVENTEEN THIRTY THREE ROBERT',
#   '<X>',
#   '<X>',
#   '<X>',
#   'SIXTEEN THIRTY ONE ROBERT',
#   '<X>',
#   'ALRIGHT YOUR FIRST ONE SIXTY THREE OH THREE CORNELIA TWO HOURS',
#   '<X>',
#   'SEVENTEEN THIRTY THREE ROBERT',
#   'ONE SEVEN THREE ONE ROBERT',
#   '<X>',
#   'ONE SEVEN FIVE THREE',
#   '<X>',
#   'ALRIGHT THEN THIRTY THREE ROBERT TAKE THESE TWO',
#   'SEVENTEEN THIRTY TWO'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   11,
#   2236,
#   'SEVENTEEN TWENTY FOUR',
#   'SIXTEEN THIRTEEN ROBERT',
#   'SEVENTEEN TWENTY FOUR',
#   'SEVENTEEN TWENTY FOUR'],
#  [27730, 'Zone1', 2018, 8, 11, 2306, 'SEVEN FIFTY '],
#  [27730, 'Zone1', 2018, 8, 11, 2335],
#  [27730, 'Zone1', 2018, 8, 12, 5],
#  [27730, 'Zone1', 2018, 8, 12, 35],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   404,
#   'SIXTEEN SEVENTY ONE ROBERT',
#   'ONE SEVEN SIX ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   434,
#   'SEVEN TWO FOUR ROBERT',
#   'THIRTY TWO ROBERT',
#   '<X>',
#   '<X>',
#   'OKAY',
#   '<X>'],
#  [27730, 'Zone1', 2018, 8, 12, 504],
#  [27730, 'Zone1', 2018, 8, 12, 533],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   603,
#   'SEVENTEEN TWENTY THREE',
#   'SIXTEEN TWENTY THREE',
#   'SIXTEEN TWENTY THREE GOOD MORNING',
#   'TEN FOUR',
#   'SIXTEEN OH ONE',
#   'TEN FOUR NOTED',
#   'SIX OH ONE',
#   'SIX OH ONE',
#   'NEED A SPANISH SPEAKING OFFICER',
#   "SIXTEEN SIX THREE THREE THAT'S SIX THREE THREE THAT'S YOU YOU'LL HELP OUT",
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY FOUR ROBERT',
#   'TEN FOUR',
#   'SEVENTEEN OH TWO',
#   'SEVENTEEN OH TWO',
#   'SIXTEEN TWENTY THREE',
#   'SIXTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   633,
#   "THAT'S SEVENTEEN TEN",
#   'SIXTEEN TWENTY THREE',
#   'SIXTEEN OH TWO',
#   'SIXTEEN OH TWO GOOD MORNING'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   703,
#   'SEVENTEEN TWENTY THREE',
#   "TWENTY THREE MA'AM",
#   'SEVENTEEN THIRTEEN',
#   'THIRTY THREE',
#   'SIXTEEN TWENTY THREE',
#   'TWENTY THREE',
#   'TEN FOUR',
#   'SIXTEEN TWENTY ONE',
#   'SIXTEEN SEVENTY ONE',
#   'ALRIGHT TEN FOUR THANKS AND GOOD MORNING',
#   'SEVENTY ONE SIR',
#   'TEN FOUR ZERO FOUR FOUR EIGHT SEVEN ZERO FOUR FOUR EIGHT SEVEN',
#   'SIXTEEN SEVENTY ONE',
#   'SEVENTY ONE',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   733,
#   'SIXTEEN FIFTY THREE',
#   'YES',
#   'ONE SIX TWO FOUR',
#   'TEN FOUR',
#   'SEVENTEEN THIRTEEN',
#   'TEN FOUR',
#   'TEEN THIRTY ONE',
#   'SIXTEEN THIRTY ONE',
#   'TEN FOUR',
#   'SIXTEEN THIRTY TWO',
#   'ONE SIX THREE TWO',
#   'SIXTEEN THIRTY TWO',
#   'DO WE HAVE A SIXTEEN THIRTY TWO OUT THERE ONE SIX THREE TWO',
#   'ONE SIX THREE TWO',
#   'SIXTEEN FIFTY THREE',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY TWO',
#   'SEVENTEEN TWENTY TWO',
#   "TWENTY TWO YOU SAID YOU'RE TEN FOUR AND YOU'RE HEADING THAT WAY",
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   803,
#   'SIX FIVE THREE',
#   'SIX FIVE THREE',
#   'ONE SIX THREE TWO',
#   'SEVENTEEN TWELVE',
#   'SEVEN TWELVE',
#   'TEN FOUR',
#   "I DIDN'T COPY",
#   'SEVEN TWO THREE',
#   'SEVENTEEN TWENTY',
#   'SEVENTEEN THIRTY TWO FOR A MOBILE ONE SEVEN THREE TWO',
#   'SEVEN TWO TWO',
#   'SEVEN TWO TWO TRY IT AGAIN',
#   'I NEED A NAME CHECK',
#   'ONE SIX THREE TWO',
#   'SEVEN TWO TWO STAND BY ONE SECOND ON THAT NAME CHECK ONE SIX THREE TWO',
#   'SIX THREE TWO SO FAR NO TAKERS',
#   'SEVENTEEN TWENTY TWO',
#   'SEVENTEEN TWENTY TWO',
#   "YOU'RE WELCOME",
#   'SIXTEEN THIRTY THREE',
#   'SIXTEEN THIRTY THREE',
#   'OKAY THANK YOU',
#   'SEVEN THREE THREE',
#   'THANK YOU',
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE',
#   'SEVEN TWO TWO',
#   'SEVEN TWO TWO TRY IT AGAIN',
#   'TEN FOUR',
#   'SEVEN THREE TWO',
#   'SEVEN THREE TWO',
#   'SIX THIRTY TWO',
#   'ONE SIX TWO ONE',
#   'ONE SIX TWO ONE',
#   'SIX TWO TWO',
#   'TWO',
#   'TEN FOUR',
#   'SIX TWO THREE',
#   'SIX FIVE TWO',
#   'SIX FIVE TWO',
#   'SEVENTEEN TWELVE',
#   'SIXTEEN SIXTY',
#   'THE EVENT NUMBER IS ZERO FIVE ZERO SIXTY ZERO FIFTY SIXTY',
#   'TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   832,
#   '<X>',
#   'ONE SEVEN TWO THREE',
#   'SEVENTEEN TWENTY FOUR',
#   '<X>',
#   'SEVEN TWO THREE',
#   'ONE SEVEN TWO THREE',
#   'SEVENTEEN TWELVE',
#   'SEVEN THIRTY TWO',
#   'SEVEN TWO TWO',
#   "SEVEN TWO TWO I CAN'T COPY BUT SEVEN THIRTY TWO YOU NEED A BACKUP",
#   "WE CAN'T COPY AT ALL",
#   'SEVEN TWO TWO GO',
#   'SIX TWO FOUR',
#   'SIX TWO FOUR',
#   'TWELVE',
#   'SIX TWELVE',
#   "SIX TWELVE WE CAN'T COPY",
#   'SIXTEEN OH TWO',
#   'SIXTEEN OH TWO',
#   'SEVENTEEN TWENTY FOUR YOU TRYING TO COME IN'],
#  [27730, 'Zone1', 2018, 8, 12, 902, 'GO AHEAD THIS IS THE RADIO SHOP'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   932,
#   'ONE TWO ONE TWO',
#   'UNIT COMING IN',
#   'LOUD AND CLEAR SIR',
#   'UNO DOS TRES CUATRO CINCO LOUD AND CLEAR',
#   'LOUD AND CLEAR ONE TWO THREE FOUR FIVE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   1032,
#   'SOUNDED GOOD',
#   'SIXTEEN SIXTY TWO CHARLIE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   1102,
#   'SIXTEEN THIRTEEN RADIO CHECK',
#   'ONE SIX THREE TWO RADIO CHECK',
#   'TEN',
#   'ONE SEVEN TWO THREE',
#   'ONE TWO THREE FOUR FIVE',
#   'ABSOLUTELY ONE TWO THREE FOUR FIVE',
#   'SEVENTEEN SEVENTY TWO RADIO CHECK ON THE ZONE ONE',
#   'TEN FOUR',
#   'SIXTEEN THIRTY THREE RADIO CHECK',
#   'RADIO CHECK',
#   'SEVENTEEN TWENTY THREE RADIO CHECK',
#   'TWENTY THREE',
#   'RADIO CHECK',
#   "GOOD SIGNAL MA'AM THANK YOU",
#   'ONE SIX TWO ONE',
#   'ONE SIX TWO ONE',
#   'TEN FOUR',
#   'SIX THIRTY ONE',
#   'SURE WHAT LOCATION',
#   'NINETY TWO ELEVEN',
#   'NINETY TWO ELEVEN',
#   'SEVENTEEN TWELVE',
#   'SEVENTEEN TWELVE',
#   'ARE WE BACK OVER ON ZONE ONE',
#   'TEN FOUR',
#   'SIXTEEN TWELVE',
#   'SEVENTEEN TWELVE',
#   'SEVENTEEN TWELVE',
#   'TEN FOUR',
#   'TEN FOUR',
#   'FOUR TWO',
#   'TEN FOUR',
#   'ONE SEVEN SEVEN TWO',
#   'SIXTEEN TWELVE',
#   'SEVEN ELEVEN',
#   'ONE SEVEN TWO THREE',
#   'TWENTY THREE',
#   'TEN FOUR',
#   'ONE SIX FIVE TWO',
#   'SIXTEEN FIFTY TWO',
#   'TEN FOUR',
#   'ONE SIX THREE FOUR',
#   'SIX THREE FOUR',
#   'SIXTEEN SIXTY TWO EDDIE',
#   'SIXTEEN SIXTY TWO EDDIE',
#   'SEVENTEEN TWELVE',
#   'FOUR',
#   'SIXTEEN THIRTY THREE',
#   'SIX THREE THREE',
#   'BELMONT AND MENARD TEN FOUR',
#   'SIXTEEN SIXTY TWO',
#   'SIXTEEN THIRTY TWO WE BACK ON THE ZONE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   1859,
#   'GO AHEAD',
#   'SIXTEEN TWENTY THREE',
#   "HEAD OVER TO LOCKWOOD UM TO SEE IF THEY'RE AT HOME AND THEN YOU CAN HEAD TO THE MCDONALDS",
#   'SEVENTEEN ELEVEN',
#   'SEVEN ELEVEN',
#   '<X> FIVE ZERO EIGHT FOUR',
#   'SEVENTEEN THIRTY TWO',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVEN FIVE TWO',
#   'SEVEN FIVE ONE',
#   'ONE SEVEN FIVE ONE',
#   'TEN FOUR',
#   'SEVENTEEN TWELVE',
#   'TEN FOUR',
#   'SEVENTEEN SIXTY ONE DAVID TEN FOUR',
#   'TEN FOUR',
#   'TWENTY FOUR',
#   'TEN FOUR',
#   "TEN FOUR WE'LL GIVE HIM A CALL",
#   'TEN FOUR',
#   'SEVENTEEN TWENTY THREE',
#   'SEVENTEEN TWENTY THREE TEN FOUR',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SEVEN FIVE TWO',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SIX TWO FOUR',
#   'SEVEN TWO THREE',
#   'SEVENTEEN ELEVEN FOR THE MOBILE',
#   'ALRIGHT TEN FOUR',
#   'SEVEN FIVE TWO',
#   'SIXTEEN THIRTY FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   1929,
#   'TEN FOUR',
#   'SEVENTEEN TWELVE',
#   'SEVENTEEN TWELVE',
#   'TEN FOUR',
#   'ONE SEVEN ONE THREE',
#   'OKAY',
#   'SIXTEEN FOURTEEN',
#   'SIXTEEN FOURTEEN',
#   'TWO',
#   'SIXTEEN THIRTY TWO',
#   'SIX THIRTY TWO',
#   'TEN FOUR',
#   'ONE SIX ONE TWO',
#   'SEVEN TWENTY',
#   'SEVEN TWENTY',
#   'TEN FOUR',
#   'TEN FOUR',
#   'SIXTEEN TWENTY TWO',
#   'ONE SIX TWO TWO',
#   'ALRIGHT TEN FOUR',
#   'SIXTEEN THIRTY TWO',
#   'TEN FOUR',
#   'SIXTEEN THIRTY',
#   'THIRTY GO AHEAD',
#   'ALRIGHT LET ME CHECK',
#   'SIXTEEN THIRTY TWO',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY FOUR',
#   'TEN FOUR',
#   'ONE SIX ONE ONE',
#   'TEN FOUR ENJOY',
#   'SIXTEEN THREE TWO',
#   'ONE SIX THREE TWO',
#   'SEVENTEEN ELEVEN COMING IN'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   1959,
#   'SIXTEEN ELEVEN COMING IN ',
#   'SEVEN TWO THREE',
#   'ONE SEVEN TWO THREE',
#   'ONE SIX TWO TWO',
#   'THREE FIVE ONE SIX WEST LELAND AVENUE',
#   'SIX TWO FOUR',
#   'TEN FOUR',
#   'ONE SIX ZERO ONE',
#   'SIXTEEN ELEVEN',
#   'TEN FOUR',
#   'ONE SEVEN SEVEN TWO',
#   'ONE SEVEN SEVEN TWO',
#   'TEN FOUR',
#   'ONE SIX THREE ONE',
#   'TWENTY TWENTY TWO ON THE CLOCK',
#   'SWITCH YOUR RADIO OVER TO B ONE',
#   'SIXTEEN TWENTY THREE',
#   'SIXTEEN TWENTY THREE',
#   'TEN FOUR',
#   'SIXTEEN TWENTY TWO',
#   'SIXTEEN TWENTY TWO',
#   'TEN FOUR',
#   'SEVENTEEN TWENTY',
#   'TRY NOW'],
#  [27730, 'Zone1', 2018, 8, 12, 2029],
#  [27730, 'Zone1', 2018, 8, 12, 2058],
#  [27730, 'Zone1', 2018, 8, 12, 2128, '<X>', '<X>'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   2158,
#   ' SIXTEEN THIRTY THREE ROBERT',
#   ' FOUR',
#   ' SIXTEEN TWENTY',
#   ' THANK YOU SIXTEEN THIRTY ROBERT',
#   ' THIRTY ROBERT',
#   ' <X>',
#   ' THIRTY TWO',
#   ' OKAY',
#   ' GEORGE UNION SIX FIVE NINE FOUR SIX',
#   ' TEN FOUR',
#   ' THIRTY ONE ROBERT',
#   ' ALRIGHT',
#   ' SEVEN THREE ONE ROBERT',
#   " SEVENTEEN THIRTY TWO THAT'S OURS",
#   ' COPY THANK YOU',
#   ' SEVENTEEN FIFTY FIVE',
#   ' <X>',
#   " FIRE'S ALREADY ROLLING",
#   ' ONE SEVEN FOUR THREE',
#   ' ALRIGHT',
#   ' SEVENTEEN FIFTY THREE',
#   ' <X>',
#   ' TEN FOUR',
#   ' TEN FOUR',
#   ' ELEVEN',
#   ' OKAY',
#   ' DAVID',
#   ' <X>',
#   ' OKAY',
#   ' JUST A LITTLE BIT',
#   ' SEVENTEEN SEVENTY TWO',
#   ' ELEVEN ROBERT',
#   ' SEVENTEEN THIRTEEN ROBERT',
#   ' THIRTEEN ROBERT',
#   ' OH OKAY',
#   ' SIX OH FIVE',
#   ' OH FIVE',
#   ' MARY ADAM LINCOLN DAVID OCEAN NORA ADAM DAVID',
#   ' THEN RICARDO',
#   ' ROBERT IDA CHARLIE ADAM ROBERT DAVID OCEAN'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   2228,
#   ' ROBERT IDA CHARLIE ADAM ROBERT DAVID OCEAN',
#   ' FIVE FIVE',
#   ' NINE ZERO NINE SIX',
#   ' ALRIGHT HANG ON',
#   ' YOU SAW TWO OF THEM RIGHT',
#   ' SEVENTEEN TEN ROBERT',
#   ' <X>',
#   ' TEN FOUR',
#   ' SIXTEEN TWENTY ONE ROBERT',
#   ' TWENTY ONE ROBERT',
#   ' <X>',
#   ' FIVE FIVE',
#   ' <X>',
#   ' SEVEN TWO FOUR',
#   ' TEN FOUR',
#   ' SIXTEEN THIRTY THREE ROBERT',
#   ' ONE SIX THREE THREE ROBERT',
#   ' SIXTEEN THIRTY THREE ROBERT',
#   " SHE DOES NOT FEEL SAFE CAUSE SHE'S KNOWN TO HANG OUT WITH GANG MEMBERS",
#   ' TEN FOUR',
#   ' SIXTEEN TWENTY TWO',
#   ' SEVENTEEN FIFTY FOUR',
#   ' CHECK THE WELL BEING ALBANY AND IRVING',
#   ' GOOD CITIZEN PASSING BY HEARD A FEMALE CRY AND THEN IT ABRUPTLY STOPPED',
#   " DOESN'T KNOW WHERE THE SOUNDS WERE COMING FROM ON THE STREET",
#   ' <X>',
#   ' SIXTEEN TWENTY THREE ROBERT',
#   ' SEVENTEEN ELEVEN ROBERT',
#   ' SEVENTEEN ELEVEN ROBERT',
#   ' SIXTEEN TWENTY TWO',
#   ' SIX TWO TWO',
#   ' ONE SIX',
#   ' TEN FOUR',
#   ' SIX OH FIVE',
#   ' THANK YOU',
#   ' SEVEN FOUR THREE',
#   ' THIRTY ROBERT',
#   ' ALRIGHT THERE WAS ONE AT TWENTY ONE SEVENTEEN TONIGHT',
#   ' A SECOND CALL AT TWENTY ONE TWENTY ONE TONIGHT',
#   ' SIX TWO FOUR',
#   ' SIX TWO FOUR',
#   ' SEVENTEEN ELEVEN ROBERT',
#   ' ELEVEN ROBERT',
#   ' HANG ON ONE MINUTE',
#   ' SEVENTEEN FIFTY THREE',
#   ' TEN FOUR',
#   ' SIXTY ONE CHARLIE',
#   ' SEVEN ONE',
#   ' EIGHT EIGHT SIX THREE',
#   ' TEN FOUR',
#   ' I GOT IT COMING BACK NO RECORD',
#   ' SEVENTEEN FIFTY FIVE',
#   ' ONE SEVEN FIVE FIVE',
#   ' TEN FOUR',
#   ' SEVENTEEN THIRTY TWO',
#   ' THIRTY TWO',
#   ' ADDISON AND DRAKE',
#   ' SEVENTEEN TWENTY FOUR',
#   ' SIXTEEN THIRTY ONE ROBERT',
#   ' FIVE THREE',
#   ' <X>',
#   ' OKAY',
#   ' SEVENTEEN FIFTY ONE',
#   ' ONE SEVEN FIVE ONE',
#   ' ONE',
#   " WHEN THE CALLER YELLED OUT AT THEM THEY GOT QUIET FOR A MINUTE BUT THEY'RE LOUD AGAIN",
#   ' OKAY',
#   ' TWENTY TWO',
#   ' ALRIGHT',
#   ' SEVEN FIVE TWO',
#   ' FIVE TWO',
#   ' YEAH WHY NOT',
#   ' THIRTY ROBERT',
#   ' THIRTY ROBERT',
#   ' OKAY',
#   ' SEVENTEEN THIRTY THREE ROBERT',
#   ' SEVEN THIRTY THREE ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   2258,
#   ' SEVENTEEN ELEVEN ROBERT',
#   ' ELEVEN ROBERT',
#   ' THE TRAFFIC CRASH ON IRVING',
#   ' OH FIVE',
#   ' <X>',
#   ' SIX TWENTY TWO',
#   ' TWENTY TWO',
#   ' UH BIG THANKS TO EVERYBODY THAT SHOWED UP',
#   ' SIX TWO THREE ROBERT',
#   ' TWENTY THREE ROBERT',
#   ' THIRTY THREE ROBERT',
#   ' TWO DRUNK FEMALES VERSUS HIM',
#   ' WITH A HAT AND SHORTS ANOTHER ONE IN A BLACK SHIRT AND SHORTS',
#   ' FOUR',
#   ' SIXTEEN NINETY SIX ROBERT',
#   ' NINETY SIX ROBERT',
#   ' SURE',
#   ' ONE SIX THREE FOUR ROBERT',
#   ' SIX THREE FOUR ROBERT',
#   " SHE'S COMPLAINING ABOUT A FEMALES OUTSIDE HER APARTMENT ARGUING",
#   ' TEN FOUR',
#   ' TWENTY THREE ROBERT',
#   ' <X>',
#   ' CHARLIE',
#   ' TRAFFIC STOP FOUR TWO FIVE THREE NORTH KIMBALL',
#   ' SIXTEEN TWENTY FOUR ROBERT',
#   ' FOUR ROBERT',
#   ' SEVENTEEN FIFTY',
#   ' ONE SEVEN FIVE THREE',
#   ' SEVENTEEN FIFTY THREE',
#   ' TEN FOUR',
#   ' THIRTY ONE ROBERT',
#   ' ONE SEVEN FIVE ONE',
#   ' FIVE ONE',
#   ' OKAY',
#   ' SEVENTEEN ELEVEN ROBERT',
#   ' SEVENTEEN ELEVEN ROBERT',
#   " YEAH SIXTY THREE THIRTY FOUR ON HAMLIN JAMES SAID THERE'S A MALE STANDING",
#   ' TALKING LOUD LAUGHING CURSING',
#   " NEVER HAD THIS BEFORE DON'T KNOW WHERE THESE GUYS CAME FROM",
#   ' TEN FOUR'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   12,
#   2328,
#   ' SEVENTEEN TWENTY TWO ROBERT',
#   ' SEVENTEEN TWENTY TWO ROBERT',
#   ' ASSIST FIFTY EIGHT THIRTY THREE',
#   ' SEVENTEEN TWENTY FOUR ROBERT',
#   ' SEVEN TWO FOUR ROBERT',
#   ' SEVENTEEN NINETY FIVE ROBERT',
#   ' AUTO ACCIDENT NOW MONTROSE AND CHRISTIANA',
#   ' TWO CARS UNSURE OF INJURY',
#   ' SEVENTEEN ELEVEN',
#   ' ELEVEN',
#   " TWENTY THREE TEN HOURS UH WE'RE JUST UH SECURING THE APARTMENT RIGHT NOW",
#   ' FIVE THREE',
#   ' OKAY',
#   ' SEVENTEEN TWENTY THREE ROBERT',
#   ' SEVENTEEN TWELVE ROBERT',
#   ' TEN FOUR',
#   ' THIRTY THREE ROBERT',
#   ' ALRIGHT SEVENTEEN TWENTY THREE ROBERT',
#   ' ONE SEVEN TWO THREE ROBERT',
#   ' <X>',
#   ' SIXTEEN FOURTEEN ROBERT',
#   ' AND A BUNCH OF CARS ARE STUCK IN THERE',
#   ' UM',
#   ' <X>',
#   ' <X>',
#   ' TWELVE ROBERT',
#   ' OKAY',
#   ' SEVEN FIVE ONE',
#   ' FIVE ONE',
#   ' <X>',
#   ' ALRIGHT',
#   ' NINETY FIVE ROBERT',
#   ' NINETY FIVE ROBERT',
#   ' <X>',
#   ' YEAH DOMESTIC FIFTY EIGHT TWENTY NINE LAWRENCE APARTMENT NUMBER TWO SECOND FLOOR',
#   ' UM',
#   ' TEN FOUR',
#   ' OKAY',
#   ' NINETY FIVE ROBERT'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   13,
#   725,
#   ' SEVENTEEN THIRTEEN',
#   ' SIXTEEN TWENTY FOUR',
#   ' TEN FOUR',
#   ' ONE SEVEN TWO TWO',
#   ' SIXTEEN TWELVE',
#   ' SIXTEEN FIFTY THREE',
#   ' SIXTEEN FORTY TWO',
#   ' ALRIGHT',
#   ' TEN FOUR',
#   " ALRIGHT MA'AM",
#   " YEAH MY PARTNER'S IN AMBULANCE THIRTY TWO WITH THE UH SUBJECT",
#   ' ALRIGHT UH TEN FOUR',
#   ' YES SIR',
#   ' ALRIGHT UH TEN FOUR',
#   ' SIXTEEN TWENTY THREE',
#   ' TEN FOUR',
#   ' ONE SIX FIVE THREE',
#   ' ONE SEVEN UH THREE THREE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   13,
#   755,
#   ' TRY IT AGAIN FOR ME',
#   ' SEVENTEEN TEN',
#   ' SEVENTEEN TEN',
#   ' ONE MORE TIME FOR ME',
#   ' THANK YOU',
#   ' [TEEN] TWENTY TWO',
#   ' SIXTEEN TWENTY TWO',
#   ' ONE SIX FOUR ONE',
#   ' ONE SIX TWO FOUR',
#   ' FIVE TWO',
#   ' SEVENTEEN SEVENTY TWO',
#   ' SEVENTEEN TEN',
#   ' SEVENTEEN TEN',
#   ' SIXTEEN FORTY ONE',
#   ' ONE SIX FOUR ONE',
#   ' FOUR ONE',
#   ' ONE SIX FOUR ONE',
#   ' ONE MORE TIME FOR ME',
#   ' SIXTEEN TWENTY ONE',
#   " UH WE'RE AT <X>",
#   ' ONE SEVEN ONE TWO',
#   ' ONE SEVEN ONE TWO',
#   ' SEVENTEEN TWENTY TWO',
#   ' ONE SEVEN THREE THREE',
#   ' ONE SEVEN THREE THREE',
#   ' SEVENTEEN TEN',
#   ' ONE SEVEN ONE ZERO'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   13,
#   825,
#   ' TEN FOUR',
#   ' TEN FOUR',
#   ' ZONE ONE TRAFFIC FOR SIXTEEN AND SEVENTEEN IS CURRENTLY ON CITYWIDE SIX',
#   ' B SIX'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   13,
#   854,
#   " RADIO [SHOP] THAT'S SOUNDING PRETTY GOOD",
#   ' THANKS FOR THE TEST',
#   ' TWO',
#   ' THREE',
#   ' FOUR',
#   ' THREE',
#   ' TWO ONE',
#   ' TEN FOUR',
#   ' TEN FOUR',
#   ' ANY OUTSIDE UNITS MONITORING ZONE ONE'],
#  [27730,
#   'Zone1',
#   2018,
#   8,
#   13,
#   924,
#   ' ONE',
#   ' TWO THREE FOUR AND FIVE',
#   ' RADIO CHECK ON CITY',
#   ' ZONE ONE',
#   ' ONE TWO THREE FOUR FIVE',
#   ' SIXTEEN TWENTY THREE']]

# %%
def check_if_same_transcription(x):

# %%
qc_snippets_dict = {}

# %%
# Find snippets for use - use transcriptions, select cases where transcribers agree (perhaps t=3 only)
qc_snippets_dict = {}

# %%
# Minimum number of snippets 
min_num_snippets = 2

# %%
# Minimum number of words (for %WER calculation)
min_num_words = 10

# %%
# Select combinatoin of snippets until both min_num_snippets and min_num_words satisfied

# %%
#
test = {'1':'test','2':'testing','3':'tested'}

# %%
import random

# %%
random.sample(list(test.items()),k=2)
# Out:
# [('2', 'testing'), ('1', 'test')]

# %%
# Calculate %WER
from jiwer import wer
error = wer(gt, hyp)
